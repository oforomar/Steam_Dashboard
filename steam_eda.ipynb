# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv('Valve_Player_Data.csv')

# %%
df.head()
# Out:
#        Month_Year  Avg_players       Gain Percent_Gain  Peak_Players  \
# 0  September 2021    512350.92     268.96       +0.05%        942519
# 1     August 2021    512081.96    6014.60       +1.19%        802544
# 2       July 2021    506067.36  -43279.72       -7.88%        763523
# 3       June 2021    549347.08 -110541.81      -16.75%        929940
# 4        May 2021    659888.89  -63457.63       -8.77%       1087197
#
#                                URL        Date  \
# 0  https://steamcharts.com/app/730  2021-09-01
# 1  https://steamcharts.com/app/730  2021-08-01
# 2  https://steamcharts.com/app/730  2021-07-01
# 3  https://steamcharts.com/app/730  2021-06-01
# 4  https://steamcharts.com/app/730  2021-05-01
#
#                           Game_Name
# 0  Counter Strike: Global Offensive
# 1  Counter Strike: Global Offensive
# 2  Counter Strike: Global Offensive
# 3  Counter Strike: Global Offensive
# 4  Counter Strike: Global Offensive

# %%
df.tail()
# Out:
#           Month_Year  Avg_players    Gain Percent_Gain  Peak_Players  \
# 5266   December 2016       192.03  -21.90      -10.24%           405
# 5267   November 2016       213.92 -134.68      -38.63%           537
# 5268    October 2016       348.60 -201.75      -36.66%          1031
# 5269  September 2016       550.36  543.26    +7654.89%          2836
# 5270     August 2016         7.10     NaN          NaN            18
#
#                                      URL        Date                 Game_Name
# 5266  https://steamcharts.com/app/435150  2016-12-01  Divinity: Original Sin 2
# 5267  https://steamcharts.com/app/435150  2016-11-01  Divinity: Original Sin 2
# 5268  https://steamcharts.com/app/435150  2016-10-01  Divinity: Original Sin 2
# 5269  https://steamcharts.com/app/435150  2016-09-01  Divinity: Original Sin 2
# 5270  https://steamcharts.com/app/435150  2016-08-01  Divinity: Original Sin 2

# %%
df.describe()
# Out:
#         Avg_players           Gain  Peak_Players
# count  5.271000e+03    5173.000000  5.271000e+03
# mean   3.763149e+04      92.071786  7.032072e+04
# std    1.032951e+05   15161.864515  1.941948e+05
# min    0.000000e+00 -250248.990000  0.000000e+00
# 25%    6.720205e+03   -1374.480000  1.302900e+04
# 50%    1.235840e+04      -0.080000  2.344700e+04
# 75%    2.414976e+04    1255.140000  4.610150e+04
# max    1.584887e+06  426446.120000  3.236027e+06

# %%
df['Date'].describe()
# Out:
# count           5271
# unique           111
# top       2021-09-01
# freq              98
# Name: Date, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5271 entries, 0 to 5270
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Month_Year    5271 non-null   object
#  1   Avg_players   5271 non-null   float64
#  2   Gain          5173 non-null   float64
#  3   Percent_Gain  5173 non-null   object
#  4   Peak_Players  5271 non-null   int64
#  5   URL           5271 non-null   object
#  6   Date          5271 non-null   object
#  7   Game_Name     5271 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 329.6+ KB

# %%
df.isnull().sum()
# Out:
# Month_Year       0
# Avg_players      0
# Gain            98
# Percent_Gain    98
# Peak_Players     0
# URL              0
# Date             0
# Game_Name        0
# dtype: int64

# %%
df[df['Gain'].isnull()]
# Out:
#          Month_Year  Avg_players  Gain Percent_Gain  Peak_Players  \
# 110       July 2012       932.57   NaN          NaN          1642
# 221       July 2012     52721.05   NaN          NaN         75041
# 276      March 2017     17551.14   NaN          NaN         67846
# 287   November 2020     74957.26   NaN          NaN        117193
# 398       July 2012     45566.90   NaN          NaN         62321
# ...             ...          ...   ...          ...           ...
# 5061      June 2020       870.49   NaN          NaN          1646
# 5141  February 2015     12871.38   NaN          NaN         45770
# 5192      June 2017         0.08   NaN          NaN             2
# 5208      June 2020      2585.63   NaN          NaN          3793
# 5270    August 2016         7.10   NaN          NaN            18
#
#                                       URL        Date  \
# 110       https://steamcharts.com/app/730  2012-07-01
# 221       https://steamcharts.com/app/570  2012-07-01
# ...

# %%
df_na = df.fillna(0)

# %%
df_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5271 entries, 0 to 5270
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Month_Year    5271 non-null   object
#  1   Avg_players   5271 non-null   float64
#  2   Gain          5271 non-null   float64
#  3   Percent_Gain  5271 non-null   object
#  4   Peak_Players  5271 non-null   int64
#  5   URL           5271 non-null   object
#  6   Date          5271 non-null   object
#  7   Game_Name     5271 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 329.6+ KB

# %%
df_na['Date'] = pd.to_datetime(df_na['Date'], format='%Y-%m')

# %%
df_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5271 entries, 0 to 5270
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Month_Year    5271 non-null   object
#  1   Avg_players   5271 non-null   float64
#  2   Gain          5271 non-null   float64
#  3   Percent_Gain  5271 non-null   object
#  4   Peak_Players  5271 non-null   int64
#  5   URL           5271 non-null   object
#  6   Date          5271 non-null   datetime64[ns]
#  7   Game_Name     5271 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 329.6+ KB

# %%
df_na.head(20)
# Out:
#         Month_Year  Avg_players       Gain Percent_Gain  Peak_Players  \
# 0   September 2021    512350.92     268.96       +0.05%        942519
# 1      August 2021    512081.96    6014.60       +1.19%        802544
# 2        July 2021    506067.36  -43279.72       -7.88%        763523
# 3        June 2021    549347.08 -110541.81      -16.75%        929940
# 4         May 2021    659888.89  -63457.63       -8.77%       1087197
# 5       April 2021    723346.52  -17581.31       -2.37%       1148077
# 6       March 2021    740927.82     -85.42       -0.01%       1198581
# 7    February 2021    741013.24   -2196.42       -0.30%       1123485
# 8     January 2021    743209.66   25405.91       +3.54%       1124553
# 9    December 2020    717803.75   49049.17       +7.33%       1164396
# 10   November 2020    668754.58   55087.89       +8.98%       1037464
# 11    October 2020    613666.69    6816.37       +1.12%        943876
# ...

# %%
twitch = pd.read_csv('Twitch_game_data.csv')

# %%
twitch
# Out:
#        Rank                              Game  Month  Year  Hours_watched  \
# 0         1                 League of Legends      1  2016       94377226
# 1         2  Counter-Strike: Global Offensive      1  2016       47832863
# 2         3                            Dota 2      1  2016       45185893
# 3         4                       Hearthstone      1  2016       39936159
# 4         5       Call of Duty: Black Ops III      1  2016       16153057
# ...     ...                               ...    ...   ...            ...
# 13795   196                            DEVOUR      9  2021         723182
# 13796   197                       War Thunder      9  2021         723003
# 13797   198                    Lost in Random      9  2021         720893
# 13798   199                       Garry's Mod      9  2021         712712
# 13799   200                      Potion Craft      9  2021         704446
#
#       Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# ...
